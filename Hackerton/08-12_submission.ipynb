# %%
import os
import glob
import re
import random
import numpy as np
import pandas as pd
from datetime import timedelta

import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
# Out:
# /Users/ddunju/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Seed & Hyperparams

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
set_seed(42)
LOOKBACK, PREDICT = 28, 7
BATCH_SIZE, EPOCHS = 16, 40
LR = 1e-3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Utils

# %%
def _read_train():
    path = './train/train.csv'
    if not os.path.exists(path):
        path = './train.csv'
    df = pd.read_csv(path)
    # ensure datetime
    df['영업일자'] = pd.to_datetime(df['영업일자'])
    return df

# %%
def _split_restaurant(name: str) -> str:
    # restaurant is the prefix before last underscore
    if isinstance(name, str) and '_' in name:
        return name.rsplit('_', 1)[0]
    return name

# %%
def _dow_one_hot(dates: np.ndarray) -> np.ndarray:
    # Monday=0..Sunday=6 -> one-hot size 7
    dows = pd.to_datetime(dates).weekday.values if hasattr(dates, "values") else pd.to_datetime(dates).weekday
    out = np.zeros((len(dates), 7), dtype=np.float32)
    for i, d in enumerate(dows):
        out[i, int(d)] = 1.0
    return out

# %%
def same_dow_median_from_last28(dates_28: np.ndarray, values_28: np.ndarray, horizon=7):
    dates_28 = pd.to_datetime(dates_28)
    med = {}
    for dow in range(7):
        mask = (dates_28.weekday == dow)
        arr = values_28[mask]
        if len(arr) > 0:
            med[dow] = float(np.median(arr))
    # fallback overall median
    overall = float(np.median(values_28)) if len(values_28) else 0.0
    last_date = dates_28.max()
    preds = []
    for h in range(1, horizon+1):
        dow = int((last_date + timedelta(days=h)).weekday())
        preds.append(med.get(dow, overall))
    return np.array(preds, dtype=np.float32)

# %%
def postprocess_from_last28(yhat: np.ndarray, last28_vals: np.ndarray, eps_floor=1.0, cap_quantile=99, cap_scale=1.2):
    # negatives -> 0
    yhat = np.maximum(yhat, 0.0)
    # epsilon floor (helps SMAPE when true > 0 but pred = 0)
    yhat = np.where(yhat == 0.0, eps_floor, yhat)
    # gentle cap to avoid huge over-forecast
    if len(last28_vals) > 0:
        cap = np.percentile(last28_vals, cap_quantile) * cap_scale
        if np.isfinite(cap) and cap > 0:
            yhat = np.minimum(yhat, cap)
    return yhat

# %% [markdown]
# ### Model

# %%
class MultiOutputLSTM(nn.Module):
    def __init__(self, input_dim=8, hidden_dim=64, num_layers=2, output_dim=7, dropout=0.1):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)     # (B, T, H)
        out = self.fc(out[:, -1]) # (B, O)
        return out

# %% [markdown]
# ### Training per item

# %%
def train_lstm(train_df: pd.DataFrame):
    trained = {}
    for key, g in tqdm(train_df.groupby('영업장명_메뉴명'), desc='Training LSTM (per item)'):
        g = g.sort_values('영업일자').copy()
        if len(g) < LOOKBACK + PREDICT:
            continue

        # scaler on qty only
        scaler = MinMaxScaler()
        qty = g[['매출수량']].values.astype(np.float32)
        qty_scaled = scaler.fit_transform(qty)  # shape (N,1)

        # DOW features for each step (no scaling)
        dows = _dow_one_hot(g['영업일자'].values)  # (N,7)

        # build windows
        X_list, Y_list = [], []
        for i in range(len(g) - LOOKBACK - PREDICT + 1):
            x_qty = qty_scaled[i:i+LOOKBACK]              # (28,1)
            x_dow = dows[i:i+LOOKBACK]                    # (28,7)
            X = np.concatenate([x_qty, x_dow], axis=1)    # (28,8)
            y = qty_scaled[i+LOOKBACK:i+LOOKBACK+PREDICT, 0]  # (7,)
            X_list.append(X)
            Y_list.append(y)

        X_train = torch.tensor(np.stack(X_list)).float().to(DEVICE)  # (B,28,8)
        y_train = torch.tensor(np.stack(Y_list)).float().to(DEVICE)  # (B,7)

        model = MultiOutputLSTM(input_dim=8, output_dim=PREDICT).to(DEVICE)
        opt = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = nn.MSELoss()

        model.train()
        for epoch in range(EPOCHS):
            idx = torch.randperm(X_train.size(0), device=DEVICE)
            for i in range(0, X_train.size(0), BATCH_SIZE):
                b = idx[i:i+BATCH_SIZE]
                xb, yb = X_train[b], y_train[b]
                pred = model(xb)
                loss = criterion(pred, yb)
                opt.zero_grad()
                loss.backward()
                opt.step()

        trained[key] = {
            'model': model.eval(),
            'scaler': scaler,
        }
    return trained

# %% [markdown]
# ### Prediction on test windows

# %%
def predict_lstm(test_df: pd.DataFrame, trained_models: dict, test_prefix: str, alpha=0.6):
    results = []
    for key, g in test_df.groupby('영업장명_메뉴명'):
        if key not in trained_models:
            continue

        g = g.sort_values('영업일자').copy()
        if len(g) < LOOKBACK:
            continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']

        # last 28
        last28_vals = g['매출수량'].values[-LOOKBACK:].astype(np.float32)
        last28_dates = pd.to_datetime(g['영업일자']).values[-LOOKBACK:]

        # features
        x_qty_scaled = scaler.transform(last28_vals.reshape(-1,1))           # (28,1)
        x_dow = _dow_one_hot(last28_dates)                                   # (28,7)
        x_input = np.concatenate([x_qty_scaled, x_dow], axis=1)[None, ...]   # (1,28,8)

        with torch.no_grad():
            pred_scaled = model(torch.tensor(x_input).float().to(DEVICE)).squeeze(0).cpu().numpy()  # (7,)

        # inverse transform
        restored = []
        for s in pred_scaled:
            tmp = scaler.inverse_transform(np.array([[s]], dtype=np.float32))[0,0]
            restored.append(float(max(tmp, 0.0)))
        restored = np.array(restored, dtype=np.float32)

        # DOW-median baseline from last 28 only
        dow_med = same_dow_median_from_last28(last28_dates, last28_vals, horizon=PREDICT)

        # blend + postprocess
        blended = alpha * restored + (1 - alpha) * dow_med
        blended = postprocess_from_last28(blended, last28_vals, eps_floor=1.0, cap_quantile=99, cap_scale=1.2)

        # pack rows
        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]
        for d, val in zip(pred_dates, blended.tolist()):
            results.append({'영업일자': d, '영업장명_메뉴명': key, '매출수량': val})
    return pd.DataFrame(results)

# %% [markdown]
# ### Submission

# %%
def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    pred_df['영업일자'] = pred_df['영업일자'].astype(str)
    pred_df['영업장명_메뉴명'] = pred_df['영업장명_메뉴명'].astype(str)
    pred_dict = dict(zip(zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']), pred_df['매출수량']))
    final_df = sample_submission.copy()
    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
    return final_df

# %%
def main():
    train_df = _read_train()
    trained = train_lstm(train_df)

    all_preds = []
    test_files = sorted(glob.glob('./test/TEST_*.csv'))
    for path in test_files:
        test_df = pd.read_csv(path)
        # ensure datetime for DOW
        try:
            test_df['영업일자'] = pd.to_datetime(test_df['영업일자'])
        except Exception:
            pass
        test_prefix = re.search(r'(TEST_\d+)', os.path.basename(path)).group(1)
        pred_df = predict_lstm(test_df, trained, test_prefix)
        all_preds.append(pred_df)

    full_pred_df = pd.concat(all_preds, ignore_index=True) if len(all_preds) else pd.DataFrame(columns=['영업일자','영업장명_메뉴명','매출수량'])

    sample_path = './sample_submission.csv'
    if not os.path.exists(sample_path):
        sample_path = '../sample_submission.csv'
    sample = pd.read_csv(sample_path)
    submission = convert_to_submission_format(full_pred_df, sample)
    submission.to_csv('baseline_submission_cv.csv', index=False, encoding='utf-8-sig')

if __name__ == "__main__":
    main()
# Out:
# Training LSTM (per item): 100%|███████████████| 193/193 [31:37<00:00,  9.83s/it]
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.6357197761535645' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.416219711303711' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.009645938873291' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1019037961959839' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9507676362991333' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.011103391647339' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.890805721282959' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3523240387439728' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5861188173294067' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3676129877567291' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5973925590515137' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.949324607849121' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.532276153564453' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8348994255065918' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6691511273384094' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2244819402694702' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.333555668592453' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2274811565876007' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.002898636506870389' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.16963267326355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.43340086936950684' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6201932430267334' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.963864326477051' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4375271797180176' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3315048217773438' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.295621395111084' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9157538414001465' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2099931240081787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.17784807085990906' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '25.205730438232422' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.396382212638855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.209449768066406' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.174001693725586' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6539965271949768' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.19065967202186584' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.23195768892765045' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9271496534347534' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.01711704209446907' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.378608703613281' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.49164992570877075' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.50363826751709' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.435896873474121' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.42535707354545593' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.287440299987793' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6034100651741028' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7627427577972412' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.36957117915153503' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.581360101699829' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4003570079803467' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8879069685935974' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.360572338104248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.718801498413086' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.93895435333252' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.254722595214844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.449899673461914' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.805109977722168' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3295021057128906' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.35320746898651123' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7179031372070312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.394657611846924' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6114411950111389' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5813417434692383' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9576597213745117' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.22373530268669128' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.32887136936187744' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.055213451385498' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3465404510498047' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.47595638036727905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5452234745025635' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6682084798812866' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1301753520965576' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.587747097015381' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.137324333190918' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5240128040313721' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.70015949010849' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3625972270965576' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3061001300811768' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9492549896240234' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.934086263179779' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4370676279067993' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.5833635330200195' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.7936882972717285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9120578169822693' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.409440517425537' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.485393524169922' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5168668031692505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4224797487258911' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.1955442577600479' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.4582483172416687' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.618465423583984' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7084879875183105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.697903573513031' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0762430727481842' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4189400672912598' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3000699281692505' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '174.86917114257812' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '48.1038818359375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9713159799575806' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7814605236053467' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.41438478231430054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7438790798187256' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.451795756816864' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2252261638641357' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.47409188747406006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3753111958503723' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.48582401871681213' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5604674220085144' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8751298189163208' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6453237533569336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8780299425125122' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.10703673958778381' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.49656343460083' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.08251743763685226' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.04461386427283287' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.03928488492965698' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.03486543893814087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0725424736738205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11338060349225998' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.29832881689071655' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.04758385568857193' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.001660819398239255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.48054102063179016' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6683899760246277' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5788872241973877' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11544764786958694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.37265250086784363' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# ...
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.5141595602035522' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.25014066696167' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.6471171379089355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.95199966430664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.9373013973236084' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.346460342407227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0776829719543457' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.1519999504089355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.110164642333984' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.95199966430664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.455708622932434' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.23969841003418' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.676000118255615' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.524018287658691' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.982986450195312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.693344116210938' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.775543212890625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.631463050842285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.95610809326172' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.239219665527344' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.064485549926758' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '84.18571472167969' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '49.05998611450195' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.311227798461914' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '36.630149841308594' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.080169677734375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.261245727539062' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.261564254760742' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.355015754699707' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.733089447021484' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.076154708862305' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5726799964904785' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.557085037231445' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.05293358489871025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '55.505558013916016' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.08802855014801025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.816201686859131' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6147748231887817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.9519484043121338' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.164894700050354' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.34524571895599365' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
# /var/folders/wz/97th05h90yjfyvrt18kyxwk40000gn/T/ipykernel_8310/3175867612.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.0919966846704483' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0.0)
